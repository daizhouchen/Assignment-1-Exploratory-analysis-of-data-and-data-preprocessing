# %% [markdown]
# # github_dataset

# %% [markdown]
# ## 数据导入

# %%
import pandas as pd
dataset=pd.read_csv("github_dataset.csv", encoding='ISO-8859-1')

# %%
dataset
# Out:
#                               repositories  stars_count  forks_count  \
# 0                      octocat/Hello-World          0.0          0.0
# 1                EddieHubCommunity/support        271.0        150.0
# 2                           ethereum/aleth          0.0          0.0
# 3                    localstack/localstack          0.0          0.0
# 4                      education/classroom          0.0        589.0
# ...                                    ...          ...          ...
# 1047              Tyriar/canvas-astar.dart          2.0          1.0
# 1048      ankitkumar70777/github-slideshow          0.0          0.0
# 1049  aitikgupta/interactive_cpu_scheduler          0.0          5.0
# 1050                gwmccubbin/voting_dapp         11.0          5.0
# 1051               gamemann/All_PropHealth          4.0          3.0
#
#       issues_count  pull_requests  contributors    language
# 0            612.0          316.0           2.0         NaN
# ...

# %% [markdown]
# ## 数据摘要

# %% [markdown]
# ###  标称属性每个可能取值的频数

# %%
dataset['repositories'].value_counts()
# Out:
# kameshsampath/ansible-role-rosa-demos         2
# aloisdeniel/bluff                             2
# antoniaandreou/github-slideshow               2
# jgthms/bulma-start                            2
# artkirienko/hlds-docker-dproto                2
#                                              ..
# WhiteHouse/CIOmanagement                      1
# 0xCaso/defillama-telegram-bot                 1
# ethereum/blake2b-py                           1
# openfoodfacts/folksonomy_mobile_experiment    1
# gamemann/All_PropHealth                       1
# Name: repositories, Length: 972, dtype: int64

# %%
dataset['language'].value_counts()
# Out:
# JavaScript          253
# Python              155
# HTML                 72
# Java                 44
# CSS                  37
# TypeScript           37
# Dart                 36
# C++                  29
# Jupyter Notebook     29
# Ruby                 28
# C                    26
# Shell                25
# PHP                  16
# Go                   15
# Rust                 10
# Swift                10
# C#                    8
# Objective-C           8
# Kotlin                7
# Makefile              6
# Jinja                 5
# SCSS                  4
# CoffeeScript          3
# Perl                  3
# Dockerfile            3
# Solidity              3
# AutoHotkey            3
# Hack                  2
# Pawn                  2
# CodeQL                2
# PowerShell            2
# Assembly              2
# Vim Script            2
# Vue                   2
# Elixir                2
# Gherkin               1
# QMake                 1
# CMake                 1
# ...

# %% [markdown]
# ### 数值属性的5数概括及缺失值的个数

# %%
dataset.describe()
# Out:
#        stars_count  forks_count  issues_count  pull_requests  contributors
# count  1052.000000  1052.000000   1052.000000    1052.000000   1052.000000
# mean     81.976236    53.884981      8.656844       4.374525      8.364068
# std     170.403116   127.699729     32.445154      27.913732     37.511807
# min       0.000000     0.000000      1.000000       0.000000      0.000000
# 25%       1.000000     1.000000      1.000000       0.000000      0.000000
# 50%      12.000000     6.000000      2.000000       0.000000      2.000000
# 75%      65.250000    38.250000      6.000000       2.000000      4.000000
# max     995.000000   973.000000    612.000000     567.000000    658.000000

# %%
dataset.isnull().sum()
# Out:
# repositories       0
# stars_count        0
# forks_count        0
# issues_count       0
# pull_requests      0
# contributors       0
# language         145
# dtype: int64

# %% [markdown]
# ## 数据可视化

# %%
import matplotlib.pyplot as plt


plt.rcParams['font.sans-serif'] = ['Microsoft YaHei']
# 绘制箱线图
plt.boxplot(x = dataset['stars_count'], # 指定绘图数据
            # 设置异常点属性，如点的形状、填充色和点的大小
            labels = [''] # 删除x轴的刻度标签，否则图形显示刻度标签为1
           )
# 添加图形标题
plt.title('stars_count')
# 显示图形
plt.show()

# %%
plt.rcParams['font.sans-serif'] = ['Microsoft YaHei']
# 绘制箱线图
plt.boxplot(x = dataset['forks_count'], # 指定绘图数据
            # 设置异常点属性，如点的形状、填充色和点的大小
            labels = [''] # 删除x轴的刻度标签，否则图形显示刻度标签为1
           )
# 添加图形标题
plt.title('forks_count')
# 显示图形
plt.show()

# %%
plt.rcParams['font.sans-serif'] = ['Microsoft YaHei']
# 绘制箱线图
plt.boxplot(x = dataset['issues_count'], # 指定绘图数据
            # 设置异常点属性，如点的形状、填充色和点的大小
            labels = [''] # 删除x轴的刻度标签，否则图形显示刻度标签为1
           )
# 添加图形标题
plt.title('issues_count')
# 显示图形
plt.show()

# %%
import matplotlib.pyplot as plt
plt.hist(dataset['pull_requests'],bins=10)
plt.title("pull_requests")
plt.show()

# %%
import matplotlib.pyplot as plt
plt.hist(dataset['contributors'],bins=10)
plt.title("contributors")
plt.show()

# %%
plt.figure(figsize=(12,10))
dataset['language'].value_counts().plot(kind='barh')
plt.title('Language')
plt.show()

# %% [markdown]
# # 数据缺失的处理

# %% [markdown]
# 用最高频率值来填补language的缺失值

# %%
mode_value = dataset['language'].mode()[0]
dataset = dataset.fillna({'language': mode_value})

# %%
dataset.isnull().sum()
# Out:
# repositories     0
# stars_count      0
# forks_count      0
# issues_count     0
# pull_requests    0
# contributors     0
# language         0
# dtype: int64

# %%
dataset
# Out:
#                               repositories  stars_count  forks_count  \
# 0                      octocat/Hello-World          0.0          0.0
# 1                EddieHubCommunity/support        271.0        150.0
# 2                           ethereum/aleth          0.0          0.0
# 3                    localstack/localstack          0.0          0.0
# 4                      education/classroom          0.0        589.0
# ...                                    ...          ...          ...
# 1047              Tyriar/canvas-astar.dart          2.0          1.0
# 1048      ankitkumar70777/github-slideshow          0.0          0.0
# 1049  aitikgupta/interactive_cpu_scheduler          0.0          5.0
# 1050                gwmccubbin/voting_dapp         11.0          5.0
# 1051               gamemann/All_PropHealth          4.0          3.0
#
#       issues_count  pull_requests  contributors    language
# 0            612.0          316.0           2.0  JavaScript
# ...

# %% [markdown]
# ##
